# %%
import cv2 as cv
from google.colab.patches import cv2_imshow

# %%
# ler imagens circulo.jpg e quadrado.jpg
f = cv.imread('1.jpg')
g = cv.imread('2.jpg')
h = cv.add(f,g)
cv2_imshow(h)
cv2_imshow(h)
# Out:
# <PIL.Image.Image image mode=RGB size=122x67>
# <PIL.Image.Image image mode=RGB size=122x67>

# %%
# ler imagens circulo.jpg e quadrado.jpg
f = cv.imread('1.jpg')
g = cv.imread('2.jpg')
h = cv.subtract(f,g)
cv2_imshow(h)
cv2_imshow(h)
# Out:
# <PIL.Image.Image image mode=RGB size=122x67>
# <PIL.Image.Image image mode=RGB size=122x67>

# %%
# ler imagens circulo.jpg e quadrado.jpg
f = cv.imread('1.jpg')
g = cv.imread('2.jpg')
h = cv.multiply(f,g)
cv2_imshow(h)
cv2_imshow(h)
# Out:
# <PIL.Image.Image image mode=RGB size=122x67>
# <PIL.Image.Image image mode=RGB size=122x67>

# %%
# ler imagens circulo.jpg e quadrado.jpg
f = cv.imread('1.jpg')
g = cv.imread('2.jpg')
h = cv.divide(f,g)
cv2_imshow(h)
cv2_imshow(h)
# Out:
# <PIL.Image.Image image mode=RGB size=122x67>
# <PIL.Image.Image image mode=RGB size=122x67>

# %%
brilho = 50
f = cv.imread('1.jpg')
h = cv.add(f,brilho)
cv2_imshow(h)
cv2_imshow(h)
# Out:
# <PIL.Image.Image image mode=RGB size=122x67>
# <PIL.Image.Image image mode=RGB size=122x67>

# %%
escurecida = 150
f = cv.imread('1.jpg')
h = cv.subtract(f,escurecida)
cv2_imshow(h)
cv2_imshow(h)
# Out:
# <PIL.Image.Image image mode=RGB size=122x67>
# <PIL.Image.Image image mode=RGB size=122x67>

# %%
contraste = 19
f = cv.imread('1.jpg')
h = cv.multiply(f,contraste)
cv2_imshow(h)
cv2_imshow(h)
# Out:
# <PIL.Image.Image image mode=RGB size=122x67>
# <PIL.Image.Image image mode=RGB size=122x67>

# %%
normalizada = 1.5
f = cv.imread('1.jpg')
h = cv.divide(f,normalizada)
cv2_imshow(h)
cv2_imshow(h)
# Out:
# <PIL.Image.Image image mode=RGB size=122x67>
# <PIL.Image.Image image mode=RGB size=122x67>
